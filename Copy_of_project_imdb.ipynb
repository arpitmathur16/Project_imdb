# %% [markdown]
# <a href="https://colab.research.google.com/github/arpitmathur16/Project_imdb/blob/main/Copy_of_project_imdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
df = pd.read_csv("/content/movies.csv")

# %%
df
# Out:
#                id                                         name  year  rating  \
# 0       tt0068646                                The Godfather  1972     9.2
# 1       tt5113044                     Minions: The Rise of Gru  2022     7.3
# 2       tt7657566                            Death on the Nile  2022     6.3
# 3       tt8115900                                 The Bad Guys  2022     6.9
# 4      tt10809742                                    Collision  2022     3.8
# ...           ...                                          ...   ...     ...
# 19803   tt0459423  Kahaani Gudiya Ki...: True Story of a Woman  2008     6.2
# 19804   tt0119621                      Mark Twain's America in  1998     6.5
# 19805   tt0168950    Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806   tt0267563                                       Hybrid  2000     7.4
# 19807   tt0116481         Hands on a Hardbody: The Documentary  1997     7.6
#
# ...

# %% [markdown]
# Q1 How do we load the dataset and see the firest 5 rows

# %%
df.head()
# Out:
#            id                      name  year  rating certificate duration  \
# 0   tt0068646             The Godfather  1972     9.2           R  175 min
# 1   tt5113044  Minions: The Rise of Gru  2022     7.3          PG   87 min
# 2   tt7657566         Death on the Nile  2022     6.3       PG-13  127 min
# 3   tt8115900              The Bad Guys  2022     6.9          PG  100 min
# 4  tt10809742                 Collision  2022     3.8       TV-MA   99 min
#
#                           genre    votes gross_income  \
# 0                  Crime, Drama  1798749  134,966,411
# 1  Animation, Adventure, Comedy    1,220  134,966,411
# 2         Crime, Drama, Mystery  121,063  134,966,411
# 3  Animation, Adventure, Comedy   23,090  134,966,411
# 4        Crime, Drama, Thriller      656  134,966,411
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# ...

# %%
df.tail()
# Out:
#               id                                         name  year  rating  \
# 19803  tt0459423  Kahaani Gudiya Ki...: True Story of a Woman  2008     6.2
# 19804  tt0119621                      Mark Twain's America in  1998     6.5
# 19805  tt0168950    Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806  tt0267563                                       Hybrid  2000     7.4
# 19807  tt0116481         Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate duration                       genre votes gross_income  \
# 19803   Not Rated  112 min            Biography, Drama    41       44,435
# 19804           G   52 min      Documentary, Biography    48    2,281,741
# 19805   Not Rated   75 min      Documentary, Biography   125        9,188
# 19806   Not Rated   92 min      Documentary, Biography   146      159,403
# 19807          PG   98 min  Documentary, Comedy, Drama  2167      492,876
#
# ...

# %%
df.sample(5)
# Out:
#               id                     name  year  rating certificate duration  \
# 3533   tt7671414                 Thriller  2018     3.6       TV-MA   87 min
# 3860   tt0273045       2001: Do Hazaar Ek  1998     3.8   Not Rated  149 min
# 5222   tt2263942             Massacre Gun  1967     7.0   Not Rated   89 min
# 2034   tt0068675           Hannie Caulder  1971     6.3           R   85 min
# 10985  tt2882912  Bratz Girlz Really Rock  2008     5.9        TV-G   78 min
#
#                           genre  votes gross_income directors_id  \
# 3533       Crime, Drama, Horror  1,221   14,688,078    nm1371010
# 3860   Crime, Mystery, Thriller    130    1,327,740    nm0802692
# 5222              Action, Crime    490      408,966    nm0367915
# 2034      Crime, Drama, Western   3431      459,650    nm0447944
# 10985                 Animation    100       52,339    nm0268741
#
#             directors_name                                 stars_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  object
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#                year        rating
# count  19808.000000  19808.000000
# mean    1995.546597      6.041973
# std       22.801725      1.206831
# min     1894.000000      1.100000
# 25%     1983.000000      5.300000
# 50%     2003.000000      6.200000
# 75%     2014.000000      6.900000
# max     2022.000000      9.700000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()  # we can also use the isna() in case of isnull() both are same
# Out:
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %%
# NULL - None
# NA - Not Aviable
# NaN - Not a Number

# %%
df["year"]
# Out:
# 0        1972
# 1        2022
# 2        2022
# 3        2022
# 4        2022
#          ...
# 19803    2008
# 19804    1998
# 19805    1998
# 19806    2000
# 19807    1997
# Name: year, Length: 19808, dtype: int64

# %% [markdown]
# Q3 - How do we clean the duratrion column ? (e.g., '175 min' to 175)

# %%
df["duration"] = df["duration"].str.replace("min", "")

# %%
df["duration"] = df["duration"].str.replace(",", "")

# %%
df["duration"] = df["duration"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 2.1+ MB

# %%
df["duration"].mean()
# Out:
# np.float64(101.77796849757674)

# %%
df["votes"] = df["votes"].str.replace(",", "")

# %%
df["votes"] = df["votes"].astype(int)

# %%
df["votes"]
# Out:
# 0        1798749
# 1           1220
# 2         121063
# 3          23090
# 4            656
#           ...
# 19803         41
# 19804         48
# 19805        125
# 19806        146
# 19807       2167
# Name: votes, Length: 19808, dtype: int64

# %%
df["gross_income"] = df["gross_income"].str.replace(",", "")

# %%
df["gross_income"] = df["gross_income"].str.replace("$", "")

# %%
df["gross_income"] = df["gross_income"].str.replace("M", "")

# %%
df["gross_income"] = df["gross_income"].str.replace(".", "")

# %%
df["gross_income"] = df["gross_income"].astype(float)

# %%
df["gross_income"]
# Out:
# 0        134966411.0
# 1        134966411.0
# 2        134966411.0
# 3        134966411.0
# 4        134966411.0
#             ...
# 19803        44435.0
# 19804      2281741.0
# 19805         9188.0
# 19806       159403.0
# 19807       492876.0
# Name: gross_income, Length: 19808, dtype: float64

# %% [markdown]
# Another way to do it
#
# df['']

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %% [markdown]
# How do we handle missing value

# %%
df.describe()
# Out:
#                year        rating      duration         votes  gross_income
# count  19808.000000  19808.000000  19808.000000  1.980800e+04  1.980800e+04
# mean    1995.546597      6.041973    101.777968  3.694303e+04  1.682198e+07
# std       22.801725      1.206831     43.178721  1.129755e+05  4.642034e+07
# min     1894.000000      1.100000      1.000000  5.000000e+00  0.000000e+00
# 25%     1983.000000      5.300000     90.000000  1.058000e+03  1.196010e+05
# 50%     2003.000000      6.200000     98.000000  4.233000e+03  1.158192e+06
# 75%     2014.000000      6.900000    111.000000  2.045350e+04  1.243278e+07
# max     2022.000000      9.700000   5220.000000  2.574832e+06  9.366622e+08

# %%
df[(df['rating'] > 6.9) & (df["votes"] < 2058.3)]
# Out:
#                id                                               name  year  \
# 1       tt5113044                           Minions: The Rise of Gru  2022
# 319    tt20420316                       Gladbeck: The Hostage Crisis  2022
# 2386    tt0021673                                       Blonde Crazy  1931
# 2718    tt0073626                                           Revolver  1973
# 2820   tt14035242                                        A Cop Movie  2021
# ...           ...                                                ...   ...
# 19799   tt1486548  Ahead of Time: The Extraordinary Journey of Ru...  2009
# 19800   tt0044917                             Amazing Monsieur Fabre  1951
# 19801   tt1334479                             Yoo-Hoo, Mrs. Goldberg  2009
# 19802   tt1518255                                          Raw Faith  2010
# 19806   tt0267563                                             Hybrid  2000
#
# ...

# %%
df[df["votes"] > 1058]
# Out:
#               id                                    name  year  rating  \
# 0      tt0068646                           The Godfather  1972     9.2
# 1      tt5113044                Minions: The Rise of Gru  2022     7.3
# 2      tt7657566                       Death on the Nile  2022     6.3
# 3      tt8115900                            The Bad Guys  2022     6.9
# 5      tt0071562                   The Godfather Part II  1974     9.0
# ...          ...                                     ...   ...     ...
# 19737  tt1972646      Eames: The Architect & The Painter  2011     7.1
# 19740  tt2174896                             To Be Takei  2014     6.9
# 19746  tt1839590  Ray Harryhausen: Special Effects Titan  2011     7.5
# 19789  tt0492499                     An Unreasonable Man  2006     7.9
# 19807  tt0116481    Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate  duration                         genre    votes  \
# ...

# %%
df[df["votes"] > 20458.3]
# Out:
#               id                   name  year  rating certificate  duration  \
# 0      tt0068646          The Godfather  1972     9.2           R       175
# 2      tt7657566      Death on the Nile  2022     6.3       PG-13       127
# 3      tt8115900           The Bad Guys  2022     6.9          PG       100
# 5      tt0071562  The Godfather Part II  1974     9.0           R       202
# 6      tt4998632              Ambulance  2022     6.1           R       136
# ...          ...                    ...   ...     ...         ...       ...
# 19374  tt2652092           The Good Lie  2014     7.4       PG-13       110
# 19385  tt7485048               Super 30  2019     7.9   Not Rated       154
# 19390  tt1035736     Coco Before Chanel  2009     6.6       PG-13       105
# 19542  tt6910020        Nothing to Lose  2018     2.3          PG       134
# 19556  tt9614460               Chhapaak  2020     5.3   Not Rated       120
#
# ...

# %% [markdown]
# Q8. Find the "overhyped" movies (Low Rating, High Gross)

# %%
df.describe()
# Out:
#                year        rating      duration         votes  gross_income
# count  19808.000000  19808.000000  19808.000000  1.980800e+04  1.980800e+04
# mean    1995.546597      6.041973    101.777968  3.694303e+04  1.682198e+07
# std       22.801725      1.206831     43.178721  1.129755e+05  4.642034e+07
# min     1894.000000      1.100000      1.000000  5.000000e+00  0.000000e+00
# 25%     1983.000000      5.300000     90.000000  1.058000e+03  1.196010e+05
# 50%     2003.000000      6.200000     98.000000  4.233000e+03  1.158192e+06
# 75%     2014.000000      6.900000    111.000000  2.045350e+04  1.243278e+07
# max     2022.000000      9.700000   5220.000000  2.574832e+06  9.366622e+08

# %%
df[(df['rating'] < 5.3) & (df["gross_income"] > 12432780)]
# Out:
#                id                         name  year  rating certificate  \
# 4      tt10809742                    Collision  2022     3.8       TV-MA
# 18     tt11656220  Midnight in the Switchgrass  2021     4.4           R
# 37      tt6749318                  Speed Kills  2018     4.2           R
# 40      tt5433138            F9: The Fast Saga  2021     5.2       PG-13
# 47      tt1551614                     Blowback  2022     4.4           R
# ...           ...                          ...   ...     ...         ...
# 18575   tt1389139        When the Bough Breaks  2016     5.1       PG-13
# 18615   tt8170298                   John Henry  2020     3.6           R
# 18616   tt6469960          An Imperfect Murder  2017     3.2           R
# 18717   tt1859573             Pretty Obsession  2012     4.2   Not Rated
# 19592   tt0074562            Gable and Lombard  1976     5.1           R
#
#        duration                      genre   votes  gross_income directors_id  \
# ...

# %% [markdown]
#  Q9. What are the unique certificates in the dataset?

# %%
df["certificate"].unique()
# Out:
# array(['R', 'PG', 'PG-13', 'TV-MA', 'Not Rated', 'Approved', 'TV-14',
#        'NC-17', 'Unrated', 'G', 'Passed', 'GP', 'X', 'M/PG', 'M', 'TV-PG',
#        'TV-G', '12', 'TV-13', 'TV-Y7-FV', 'MA-17', 'AO', '18', 'R-15',
#        'R-12', 'R-18', 'PG-12', '6+', 'TV-Y7', 'TV-Y', 'MA-13'],
#       dtype=object)

# %% [markdown]
# How many Unique values are there

# %%
df["certificate"].nunique()
# Out:
# 31

# %% [markdown]
# Q10. How many movies were released each year?

# %%
df['year'].value_counts().sort_index(ascending=True)
# Out:
# year
# 1894      1
# 1898      1
# 1902      2
# 1903      1
# 1913      3
#        ...
# 2018    736
# 2019    657
# 2020    467
# 2021    470
# 2022    174
# Name: count, Length: 114, dtype: int64

# %% [markdown]
# Another way to find the movie releases in a year

# %%
df.groupby("year")["id"].count().sort_index(ascending=False)
# Out:
# year
# 2022    174
# 2021    470
# 2020    467
# 2019    657
# 2018    736
#        ...
# 1913      3
# 1903      1
# 1902      2
# 1898      1
# 1894      1
# Name: id, Length: 114, dtype: int64

# %%
x = df["genre"].str.split(",").explode()

x = x.str.strip()

# %%
x.value_counts().sort_values(ascending= False).head(10)
# Out:
# genre
# Drama        9655
# Action       5290
# Crime        5244
# Comedy       4641
# Thriller     4231
# Adventure    3313
# Horror       3143
# Mystery      2211
# Romance      1815
# Biography    1582
# Name: count, dtype: int64

# %% [markdown]
# Q12. Which directors have the most movies ?

# %%
df.head(5)
# Out:
#            id                      name  year  rating certificate  duration  \
# 0   tt0068646             The Godfather  1972     9.2           R       175
# 1   tt5113044  Minions: The Rise of Gru  2022     7.3          PG        87
# 2   tt7657566         Death on the Nile  2022     6.3       PG-13       127
# 3   tt8115900              The Bad Guys  2022     6.9          PG       100
# 4  tt10809742                 Collision  2022     3.8       TV-MA        99
#
#                           genre    votes  gross_income  \
# 0                  Crime, Drama  1798749   134966411.0
# 1  Animation, Adventure, Comedy     1220   134966411.0
# 2         Crime, Drama, Mystery   121063   134966411.0
# 3  Animation, Adventure, Comedy    23090   134966411.0
# 4        Crime, Drama, Thriller      656   134966411.0
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# ...

# %%
y = df["directors_name"].str.split(",").explode()

y = y.str.strip()

# %%
y.value_counts().sort_values(ascending= False).head(10)
# Out:
# directors_name
# Clint Eastwood      38
# Alfred Hitchcock    38
# Henry Hathaway      31
# John Ford           31
# Raoul Walsh         31
# Steven Spielberg    30
# John Huston         29
# Jesús Franco        28
# Martin Scorsese     26
# Gordon Douglas      26
# Name: count, dtype: int64

# %% [markdown]
# Q13. Do longer movies get bettere ratings?

# %%
df[["duration","rating"]].corr()
# Out:
#           duration    rating
# duration  1.000000  0.130112
# rating    0.130112  1.000000

# %%
df[["votes", "gross_income"]].corr()
# Out:
#                  votes  gross_income
# votes         1.000000      0.632683
# gross_income  0.632683      1.000000

# %%
df[["certificate", "gross_income"]].corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7790/2447544397.py in <cell line: 0>()
# ----> 1 df[["certificate", "gross_income"]].corr()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %% [markdown]
# Q14. Which genre have the highest rating ?

# %%
df
# Out:
#                id                                         name  year  rating  \
# 0       tt0068646                                The Godfather  1972     9.2
# 1       tt5113044                     Minions: The Rise of Gru  2022     7.3
# 2       tt7657566                            Death on the Nile  2022     6.3
# 3       tt8115900                                 The Bad Guys  2022     6.9
# 4      tt10809742                                    Collision  2022     3.8
# ...           ...                                          ...   ...     ...
# 19803   tt0459423  Kahaani Gudiya Ki...: True Story of a Woman  2008     6.2
# 19804   tt0119621                      Mark Twain's America in  1998     6.5
# 19805   tt0168950    Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806   tt0267563                                       Hybrid  2000     7.4
# 19807   tt0116481         Hands on a Hardbody: The Documentary  1997     7.6
#
# ...

# %%
df.assign(genre = df["genre"].str.split(",")).explode("genre")
# Out:
#               id                                  name  year  rating  \
# 0      tt0068646                         The Godfather  1972     9.2
# 0      tt0068646                         The Godfather  1972     9.2
# 1      tt5113044              Minions: The Rise of Gru  2022     7.3
# 1      tt5113044              Minions: The Rise of Gru  2022     7.3
# 1      tt5113044              Minions: The Rise of Gru  2022     7.3
# ...          ...                                   ...   ...     ...
# 19806  tt0267563                                Hybrid  2000     7.4
# 19806  tt0267563                                Hybrid  2000     7.4
# 19807  tt0116481  Hands on a Hardbody: The Documentary  1997     7.6
# 19807  tt0116481  Hands on a Hardbody: The Documentary  1997     7.6
# 19807  tt0116481  Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate  duration        genre    votes  gross_income  \
# 0               R       175        Crime  1798749   134966411.0
# ...

# %%
df.head(2)
# Out:
#           id                      name  year  rating certificate  duration  \
# 0  tt0068646             The Godfather  1972     9.2           R       175
# 1  tt5113044  Minions: The Rise of Gru  2022     7.3          PG        87
#
#                           genre    votes  gross_income  \
# 0                  Crime, Drama  1798749   134966411.0
# 1  Animation, Adventure, Comedy     1220   134966411.0
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# 1  nm0049633,nm1556070,nm3646390  Kyle Balda,Brad Ableson,Jonathan del Val
#
#                                   stars_id  \
# 0  nm0000008,nm0000199,nm0001001,nm0000473
# 1  nm0136797,nm1853544,nm0000273,nm0378245
#
#                                           stars_name  \
# 0    Marlon Brando,Al Pacino,James Caan,Diane Keaton
# 1  Steve Carell,Pierre Coffin,Alan Arkin,Taraji P...
#
# ...

# %%
df2.groupby("genre")["rating"].mean().sort_values(ascending = False).head(5)
# Out:
# genre
# Documentary    7.187100
#  Short         7.117143
#  Reality-TV    7.100000
#  Biography     7.090317
# Short          6.997674
# Name: rating, dtype: float64
